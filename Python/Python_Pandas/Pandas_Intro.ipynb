# %%
import pandas as pd

df = pd.read_csv("orders - Copy.csv")

# %%
print(df)
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
# Prints first 5 rows
df.head()
# Out:
#    OrderID   CustomerName       Product     Category  Quantity   Price  \
# 0     1001     John Smith        Laptop  Electronics         1  1200.0
# 1     1002      Sarah Lee    Headphones  Electronics         2   150.0
# 2     1003       Ali Khan  Office Chair    Furniture         1   300.0
# 3     1004     Alice Wong     Desk Lamp    Furniture         3    45.0
# 4     1005  Carlos Mendez      Keyboard  Electronics         2    80.0
#
#     OrderDate Shipped    Country
# 0  2024-06-01     Yes        USA
# 1  2024-06-03      No     Canada
# 2  2024-06-04     Yes        UAE
# 3  2024-06-05     Yes  Singapore
# 4  2024-06-06      No     Mexico

# %%
# Prints last 5 rows
df.tail()
# Out:
#     OrderID    CustomerName             Product     Category  Quantity  Price  \
# 35     1036   Emma Thompson  Desk Lamp with USB    Furniture         1   68.0
# 36     1037   Carlos Santos    Wireless Earbuds  Electronics         1  125.0
# 37     1038  Leila Mansouri            Desk Pad    Furniture         1   28.0
# 38     1039      Daniel Kim         Power Strip  Electronics         2   18.0
# 39     1040    Anna Ivanova          Desk Clock    Furniture         1   35.0
#
#      OrderDate Shipped      Country
# 35  2024-07-07      No           UK
# 36  2024-07-08     Yes     Portugal
# 37  2024-07-09     Yes         Iran
# 38  2024-07-10      No  South Korea
# 39  2024-07-11     Yes      Ukraine

# %%
# Prints general info on the dataframe such as total columns, index
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       40 non-null     int64
#  1   CustomerName  40 non-null     object
#  2   Product       40 non-null     object
#  3   Category      40 non-null     object
#  4   Quantity      40 non-null     int64
#  5   Price         40 non-null     float64
#  6   OrderDate     40 non-null     object
#  7   Shipped       40 non-null     object
#  8   Country       40 non-null     object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 2.9+ KB

# %%
# Generates a table for us which displays descriptive statistics
df.describe()
# Out:
#            OrderID    Quantity        Price
# count    40.000000   40.000000    40.000000
# mean   1020.500000    5.450000   106.457500
# std      11.690452   15.903475   201.091854
# min    1001.000000    1.000000     0.800000
# 25%    1010.750000    1.000000    18.000000
# 50%    1020.500000    1.000000    43.500000
# 75%    1030.250000    2.250000   112.500000
# max    1040.000000  100.000000  1200.000000

# %%
# To get list of columns
df.columns
# Out:
# Index(['OrderID', 'CustomerName', 'Product', 'Category', 'Quantity', 'Price',
#        'OrderDate', 'Shipped', 'Country'],
#       dtype='object')

# %%
# Displays range here that allows us to step over the data frame
df.index
# Out:
# RangeIndex(start=0, stop=40, step=1)

# %%
# To index all the values that are inside the country column
df["Country"]
# Out:
# 0              USA
# 1           Canada
# 2              UAE
# 3        Singapore
# 4           Mexico
# 5              UAE
# 6               UK
# 7      South Korea
# 8            Italy
# 9            Japan
# 10          France
# 11           India
# 12       Australia
# 13           Spain
# 14           China
# 15           Egypt
# 16          Poland
# 17             USA
# 18           Japan
# 19    Saudi Arabia
# 20          Canada
# 21          Brazil
# 22         Germany
# 23        Pakistan
# 24          Sweden
# 25          France
# 26       Argentina
# 27          Russia
# 28     South Korea
# 29           Italy
# 30         Morocco
# 31         Germany
# 32        Colombia
# 33             USA
# 34           Japan
# 35              UK
# 36        Portugal
# 37            Iran
# 38     South Korea
# 39         Ukraine
# Name: Country, dtype: object

# %%
# To print length of the country series
len(df["Country"])
# Out:
# 40

# %%
# To display unique set of values, use set function which will give us all the unique values
set(df["Country"])
# Out:
# {'Argentina',
#  'Australia',
#  'Brazil',
#  'Canada',
#  'China',
#  'Colombia',
#  'Egypt',
#  'France',
#  'Germany',
#  'India',
#  'Iran',
#  'Italy',
#  'Japan',
#  'Mexico',
#  'Morocco',
#  'Pakistan',
#  'Poland',
#  'Portugal',
#  'Russia',
#  'Saudi Arabia',
#  'Singapore',
#  'South Korea',
#  'Spain',
#  'Sweden',
#  'UAE',
#  'UK',
#  'USA',
#  'Ukraine'}

# %%
# To show different columns at once.
df[["Country", "Product"]]
# Out:
#          Country                Product
# 0            USA                 Laptop
# 1         Canada             Headphones
# 2            UAE           Office Chair
# 3      Singapore              Desk Lamp
# 4         Mexico               Keyboard
# 5            UAE               Notebook
# 6             UK          Standing Desk
# 7    South Korea                Monitor
# 8          Italy                    Pen
# 9          Japan                  Mouse
# 10        France                 Webcam
# 11         India           File Cabinet
# 12     Australia                Stapler
# 13         Spain              USB Drive
# 14         China              Bookshelf
# 15         Egypt          Printer Paper
# 16        Poland         Wireless Mouse
# 17           USA         Desk Organizer
# 18         Japan             Calculator
# 19  Saudi Arabia             Whiteboard
# 20        Canada           Highlighters
# 21        Brazil      Bluetooth Speaker
# ...

# %%
# To index based out of rows use iloc() = index location.
# This will display the entire row of 0th index
df.iloc[0]

# To convert the output to a list
#list(df.iloc[0])
# Out:
# OrderID                1001
# CustomerName     John Smith
# Product              Laptop
# Category        Electronics
# Quantity                  1
# Price                1200.0
# OrderDate        2024-06-01
# Shipped                 Yes
# Country                 USA
# Name: 0, dtype: object

# %%
# We can reference by column name
df.iloc[10]["Shipped"]
# Out:
# 'Yes'

# %%
# Filtering dataframe
df[df["Category"] == "Electronics"]
# Out:
#     OrderID      CustomerName            Product     Category  Quantity  \
# 0      1001        John Smith             Laptop  Electronics         1
# 1      1002         Sarah Lee         Headphones  Electronics         2
# 4      1005     Carlos Mendez           Keyboard  Electronics         2
# 7      1008        James Park            Monitor  Electronics         2
# 9      1010  Takeshi Nakamura              Mouse  Electronics         1
# 10     1011     Sophie Martin             Webcam  Electronics         1
# 13     1014   Diego Rodriguez          USB Drive  Electronics         5
# 16     1017     Anna Kowalski     Wireless Mouse  Electronics         2
# 18     1019       Yuki Tanaka         Calculator  Electronics         1
# 21     1022    Isabella Silva  Bluetooth Speaker  Electronics         1
# 24     1025    Lucas Anderson       Tablet Stand  Electronics         1
# 25     1026      Chloe Dubois     Paper Shredder  Electronics         1
# ...

# %%
# Filtering dataframe by applying multiple conditions
# We want to check the category is electronics and in USA
df[(df["Category"] == "Electronics") & (df["Country"] == "USA")]
# Out:
#    OrderID CustomerName Product     Category  Quantity   Price   OrderDate  \
# 0     1001   John Smith  Laptop  Electronics         1  1200.0  2024-06-01
#
#   Shipped Country
# 0     Yes     USA

# %%
# Filtering dataframe by applying multiple conditions
# We want to check the category is electronics or Country is USA
df[(df["Category"] == "Electronics") | (df["Country"] == "USA")]
# Out:
#     OrderID      CustomerName            Product     Category  Quantity  \
# 0      1001        John Smith             Laptop  Electronics         1
# 1      1002         Sarah Lee         Headphones  Electronics         2
# 4      1005     Carlos Mendez           Keyboard  Electronics         2
# 7      1008        James Park            Monitor  Electronics         2
# 9      1010  Takeshi Nakamura              Mouse  Electronics         1
# 10     1011     Sophie Martin             Webcam  Electronics         1
# 13     1014   Diego Rodriguez          USB Drive  Electronics         5
# 16     1017     Anna Kowalski     Wireless Mouse  Electronics         2
# 17     1018     Michael Brown     Desk Organizer    Furniture         1
# 18     1019       Yuki Tanaka         Calculator  Electronics         1
# 21     1022    Isabella Silva  Bluetooth Speaker  Electronics         1
# 24     1025    Lucas Anderson       Tablet Stand  Electronics         1
# ...

# %%
# To filter out dataframe with Quantity > 2
df[df["Quantity"] > 2]
# df[df["Quantity"] <= 2]
# df[df["Quantity"] != 2]
# Out:
#     OrderID     CustomerName        Product     Category  Quantity  Price  \
# 3      1004       Alice Wong      Desk Lamp    Furniture         3   45.0
# 5      1006     Nora Ibrahim       Notebook   Stationery         5    5.0
# 8      1009      Maria Rossi            Pen   Stationery        10    1.5
# 12     1013      Emma Wilson        Stapler   Stationery         3   12.0
# 13     1014  Diego Rodriguez      USB Drive  Electronics         5   25.0
# 15     1016     Ahmed Hassan  Printer Paper   Stationery        20    8.0
# 20     1021   David Thompson   Highlighters   Stationery         8    3.5
# 23     1024       Zara Ahmed   Sticky Notes   Stationery        15    4.0
# 27     1028      Nina Petrov   Binder Clips   Stationery        12    2.5
# 33     1034     Alex Johnson    Index Cards   Stationery       100    0.8
#
#      OrderDate Shipped    Country
# 3   2024-06-05     Yes  Singapore
# 5   2024-06-07     Yes        UAE
# 8   2024-06-10     Yes      Italy
# ...

# %%
# To filter dataframe whose name starts with 'A'
df[df["CustomerName"].str.startswith('A')]

# To filter dataframe whose name ends with 'a'
# df[df["CustomerName"].str.endswith('a')]
# Out:
#     OrderID   CustomerName         Product     Category  Quantity  Price  \
# 2      1003       Ali Khan    Office Chair    Furniture         1  300.0
# 3      1004     Alice Wong       Desk Lamp    Furniture         3   45.0
# 15     1016   Ahmed Hassan   Printer Paper   Stationery        20    8.0
# 16     1017  Anna Kowalski  Wireless Mouse  Electronics         2   45.0
# 30     1031   Amira Hassan         USB Hub  Electronics         1   32.0
# 33     1034   Alex Johnson     Index Cards   Stationery       100    0.8
# 39     1040   Anna Ivanova      Desk Clock    Furniture         1   35.0
#
#      OrderDate Shipped    Country
# 2   2024-06-04     Yes        UAE
# 3   2024-06-05     Yes  Singapore
# 15  2024-06-17     Yes      Egypt
# 16  2024-06-18     Yes     Poland
# 30  2024-07-02     Yes    Morocco
# 33  2024-07-05     Yes        USA
# 39  2024-07-11     Yes    Ukraine

# %%
# To filter dataframe whose country is in following countries.
# So, instead of combine condition we can use 'isin' operator
df[df["Country"].isin(["USA", "Sweden", "Brazil"])]
# Out:
#     OrderID    CustomerName            Product     Category  Quantity   Price  \
# 0      1001      John Smith             Laptop  Electronics         1  1200.0
# 17     1018   Michael Brown     Desk Organizer    Furniture         1    65.0
# 21     1022  Isabella Silva  Bluetooth Speaker  Electronics         1    95.0
# 24     1025  Lucas Anderson       Tablet Stand  Electronics         1    28.0
# 33     1034    Alex Johnson        Index Cards   Stationery       100     0.8
#
#      OrderDate Shipped Country
# 0   2024-06-01     Yes     USA
# 17  2024-06-19      No     USA
# 21  2024-06-23     Yes  Brazil
# 24  2024-06-26     Yes  Sweden
# 33  2024-07-05     Yes     USA

# %%
# And to reverse above condition we use ~ to exclude USA, Sweden and Brazil countries
df[~df["Country"].isin(["USA", "Sweden", "Brazil"])]
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# 11     1012         Raj Patel           File Cabinet    Furniture         2
# ...

# %%
# Updating Data in a Dataframe
# Delete and Update data
# We use .loc() to locate based on some label.
# A label is basically any entry that's inside a row rather than the index

# Want to locate a row where the customer name is equal to Anna
# Output will show in a dataframe format
df.loc[df["CustomerName"] == "Anna Ivanova"]
# Out:
#     OrderID  CustomerName     Product   Category  Quantity  Price   OrderDate  \
# 39     1040  Anna Ivanova  Desk Clock  Furniture         1   35.0  2024-07-11
#
#    Shipped  Country
# 39     Yes  Ukraine

# %%
# To change Product field for Anna Ivanova
df.loc[df["CustomerName"] == "Anna Ivanova", "Product"] = "Tim"

# %%
# To view the updated product field, changed from Desk Clock to Tim for Anna Ivanova
df.loc[df["CustomerName"] == "Anna Ivanova"]
# Out:
#     OrderID  CustomerName Product   Category  Quantity  Price   OrderDate  \
# 39     1040  Anna Ivanova     Tim  Furniture         1   35.0  2024-07-11
#
#    Shipped  Country
# 39     Yes  Ukraine

# %%
# Another Example, is to change all Countries with the USA to United States
df.loc[df["Country"] == "USA", "Country"] = "United States"

# %%
# To view the updated Dataframe
df.loc[df["Country"] == "United States"]
# Out:
#     OrderID   CustomerName         Product     Category  Quantity   Price  \
# 0      1001     John Smith          Laptop  Electronics         1  1200.0
# 17     1018  Michael Brown  Desk Organizer    Furniture         1    65.0
# 33     1034   Alex Johnson     Index Cards   Stationery       100     0.8
#
#      OrderDate Shipped        Country
# 0   2024-06-01     Yes  United States
# 17  2024-06-19      No  United States
# 33  2024-07-05     Yes  United States

# %%
# To convert our dataframe to Uppercase
df["Country"] = df["Country"].str.upper()

# %%
# To view the country in uppercase
df["Country"]
# Out:
# 0     UNITED STATES
# 1            CANADA
# 2               UAE
# 3         SINGAPORE
# 4            MEXICO
# 5               UAE
# 6                UK
# 7       SOUTH KOREA
# 8             ITALY
# 9             JAPAN
# 10           FRANCE
# 11            INDIA
# 12        AUSTRALIA
# 13            SPAIN
# 14            CHINA
# 15            EGYPT
# 16           POLAND
# 17    UNITED STATES
# 18            JAPAN
# 19     SAUDI ARABIA
# 20           CANADA
# 21           BRAZIL
# 22          GERMANY
# 23         PAKISTAN
# 24           SWEDEN
# 25           FRANCE
# 26        ARGENTINA
# 27           RUSSIA
# 28      SOUTH KOREA
# 29            ITALY
# 30          MOROCCO
# 31          GERMANY
# 32         COLOMBIA
# 33    UNITED STATES
# 34            JAPAN
# 35               UK
# 36         PORTUGAL
# 37             IRAN
# 38      SOUTH KOREA
# 39          UKRAINE
# Name: Country, dtype: object

# %%
# To remove few entries from our dataframe
# Below is to delete the row that's at index 39
df = df.drop(39)

# %%
# To view the result, if 39th row is dropped
df.tail()
# Out:
#     OrderID    CustomerName             Product     Category  Quantity  Price  \
# 34     1035   Yuki Yamamoto       Monitor Stand  Electronics         1   55.0
# 35     1036   Emma Thompson  Desk Lamp with USB    Furniture         1   68.0
# 36     1037   Carlos Santos    Wireless Earbuds  Electronics         1  125.0
# 37     1038  Leila Mansouri            Desk Pad    Furniture         1   28.0
# 38     1039      Daniel Kim         Power Strip  Electronics         2   18.0
#
#      OrderDate Shipped      Country
# 34  2024-07-06     Yes        JAPAN
# 35  2024-07-07      No           UK
# 36  2024-07-08     Yes     PORTUGAL
# 37  2024-07-09     Yes         IRAN
# 38  2024-07-10      No  SOUTH KOREA

# %%
# Cleaning Dataframe
# To drop any N/A or blank entries in a row, we use df.dropna()
# df.dropna(): drop anything that contains any null values or NA values
df.dropna()
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
# To fill our desired entries where row entires are blank. We use df.fillna()
# For example, If we want to fill 0 where N/A value is there for OrderID column
# inplace= True, means modify the existing dataframe not return you a new dataframe
df.fillna({"OrderID": 0}, inplace=True)

# %%
# To rename columns
# For example, to rename OrderID to Order ID
df.rename(columns={"OrderID": "Order ID"}, inplace=True)

# %%
# To view the updated dataframe with updated column
df
# Out:
#     Order ID      CustomerName                Product     Category  Quantity  \
# 0       1001        John Smith                 Laptop  Electronics         1
# 1       1002         Sarah Lee             Headphones  Electronics         2
# 2       1003          Ali Khan           Office Chair    Furniture         1
# 3       1004        Alice Wong              Desk Lamp    Furniture         3
# 4       1005     Carlos Mendez               Keyboard  Electronics         2
# 5       1006      Nora Ibrahim               Notebook   Stationery         5
# 6       1007       Emily Davis          Standing Desk    Furniture         1
# 7       1008        James Park                Monitor  Electronics         2
# 8       1009       Maria Rossi                    Pen   Stationery        10
# 9       1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10      1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
# To Analyze data

# Value Counts for a particular Column type
df["Country"].value_counts()
# Out:
# Country
# UNITED STATES    3
# JAPAN            3
# SOUTH KOREA      3
# UAE              2
# CANADA           2
# ITALY            2
# UK               2
# FRANCE           2
# GERMANY          2
# SINGAPORE        1
# MEXICO           1
# INDIA            1
# AUSTRALIA        1
# CHINA            1
# SPAIN            1
# EGYPT            1
# POLAND           1
# SAUDI ARABIA     1
# BRAZIL           1
# PAKISTAN         1
# SWEDEN           1
# ARGENTINA        1
# RUSSIA           1
# MOROCCO          1
# COLOMBIA         1
# PORTUGAL         1
# IRAN             1
# Name: count, dtype: int64

# %%
# Group By
df.groupby("Country")["Price"].sum()

# O/P: It's going to sum the total price of all the products grouped by countries.
# Out:
# Country
# ARGENTINA          22.0
# AUSTRALIA          12.0
# BRAZIL             95.0
# CANADA            153.5
# CHINA             280.0
# COLOMBIA           42.0
# EGYPT               8.0
# FRANCE            160.0
# GERMANY           175.0
# INDIA             180.0
# IRAN               28.0
# ITALY              19.5
# JAPAN             105.0
# MEXICO             80.0
# MOROCCO            32.0
# PAKISTAN            4.0
# POLAND             45.0
# PORTUGAL          125.0
# RUSSIA              2.5
# SAUDI ARABIA      120.0
# SINGAPORE          45.0
# SOUTH KOREA       348.0
# SPAIN              25.0
# SWEDEN             28.0
# UAE               305.0
# UK                518.0
# UNITED STATES    1265.8
# Name: Price, dtype: float64

# %%
# Sorting of dataframe, by Price values in ascending order
df.sort_values("Price", ascending=True)
# Out:
#     Order ID      CustomerName                Product     Category  Quantity  \
# 33      1034      Alex Johnson            Index Cards   Stationery       100
# 8       1009       Maria Rossi                    Pen   Stationery        10
# 27      1028       Nina Petrov           Binder Clips   Stationery        12
# 20      1021    David Thompson           Highlighters   Stationery         8
# 23      1024        Zara Ahmed           Sticky Notes   Stationery        15
# 5       1006      Nora Ibrahim               Notebook   Stationery         5
# 15      1016      Ahmed Hassan          Printer Paper   Stationery        20
# 12      1013       Emma Wilson                Stapler   Stationery         3
# 18      1019       Yuki Tanaka             Calculator  Electronics         1
# 29      1030   Giuseppe Romano          Desk Calendar    Furniture         1
# 38      1039        Daniel Kim            Power Strip  Electronics         2
# ...

# %%
# If we want to save the dataframe to another file --> new_file.csv
# And if we want to include indexes we can (index=True)
# Once run, the new file will be shown in the directory of the codebase. In this case, under Python >>> Python_Pandas
df.to_csv("new_file.csv", index=False)
